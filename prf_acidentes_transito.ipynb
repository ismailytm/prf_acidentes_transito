# %% [markdown]
# # 1\. Introdução
# Visualização e Predição de Severidade dos acidentes registrados pela Polícia Rodiviária Federal entre os anos de 2017 e 2022.

# %% [markdown]
# # 2\. Bibliotecas e Datasets

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# import pandas as pd
# import glob

# # Path of directory containing the CSV files
# path = 'data'

# # Get all CSV files in the directory
# all_files = glob.glob(path + "/*.csv")

# # Read all CSV files and store them in a list
# data_list = []
# for filename in all_files:
#     df = pd.read_csv(filename, sep=';', encoding='cp1252')
#     data_list.append(df)

# # Concatenate all CSV files into a single DataFrame
# merged_df = pd.concat(data_list, axis=0, ignore_index=True)

# # Save as a newfile
# merged_df.to_csv('data\\merged_acidentes2017a2022.csv')

# # Display the merged DataFrame
# merged_df.head()

# %%
# dftrans_17 = pd.read_csv('data/acidentes2017_todas_causas_tipos.csv', sep=';', encoding='cp1252')
# dftrans_18 = pd.read_csv('data/acidentes2018_todas_causas_tipos.csv', sep=';', encoding='cp1252')
# dftrans_19 = pd.read_csv('data/acidentes2019_todas_causas_tipos.csv', sep=';', encoding='cp1252')
# dftrans_20 = pd.read_csv('data/acidentes2020_todas_causas_tipos.csv', sep=';', encoding='cp1252')
# dftrans_21 = pd.read_csv('data/acidentes2021_todas_causas_tipos.csv', sep=';', encoding='cp1252')
# dftrans_22 = pd.read_csv('data/acidentes2022_todas_causas_tipos.csv', sep=';', encoding='cp1252')

# %%
dftrans = pd.read_csv('data/merged_acidentes2017a2022.csv')
# Out:
# C:\Users\smile\AppData\Local\Temp\ipykernel_2692\603427295.py:1: DtypeWarning: Columns (33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   dftrans = pd.read_csv('data/merged_acidentes2017a2022.csv')

# %%
dftrans.iloc[0:6,33:35]
# Out:
#        latitude     longitude
# 0  -23,09880731  -52,38789369
# 1      -27,8101      -48,6357
# 2  -23,36951985  309,93513107
# 3  -23,36951985  309,93513107
# 4  -16,27473677  -48,96908998
# 5  -26,44675249  -49,20166969

# %%
dftrans.head()
# Out:
#    Unnamed: 0    id   pesid data_inversa dia_semana   horario  uf     br
# 0           0   8.0     1.0   2017-01-01    domingo  00:00:00  PR  376.0  \
# 1           1   9.0   955.0   2017-01-01    domingo  00:01:00  SC  101.0
# 2           2  11.0     2.0   2017-01-01    domingo  00:00:00  PR  153.0
# 3           3  11.0     3.0   2017-01-01    domingo  00:00:00  PR  153.0
# 4           4  12.0  1499.0   2017-01-01    domingo  00:00:00  GO  153.0
#
#      km                 municipio  ...       sexo ilesos  feridos_leves
# 0   112                 PARANAVAI  ...  Masculino      0              0  \
# 1   234                   PALHOCA  ...  Masculino      1              0
# 2  56,9  SANTO ANTONIO DA PLATINA  ...   Feminino      0              1
# 3  56,9  SANTO ANTONIO DA PLATINA  ...  Masculino      0              1
# 4   435                  ANAPOLIS  ...  Masculino      0              0
#
#   feridos_graves mortos      latitude     longitude regional delegacia
# 0              1      0  -23,09880731  -52,38789369  SPRF-PR  DEL07-PR  \
# 1              0      0      -27,8101      -48,6357  SPRF-SC  DEL01-SC
# 2              0      0  -23,36951985  309,93513107  SPRF-PR  DEL07-PR
# 3              0      0  -23,36951985  309,93513107  SPRF-PR  DEL07-PR
# 4              1      0  -16,27473677  -48,96908998  SPRF-GO  DEL02-GO
#
#               uop
# 0  UOP02-DEL09-PR
# 1  UOP02-DEL01-SC
# 2  UOP04-DEL07-PR
# 3  UOP04-DEL07-PR
# 4  UOP01-DEL02-GO
#
# [5 rows x 38 columns]

# %%
dftrans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2367915 entries, 0 to 2367914
# Data columns (total 38 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0              int64
#  1   id                      float64
#  2   pesid                   float64
#  3   data_inversa            object
#  4   dia_semana              object
#  5   horario                 object
#  6   uf                      object
#  7   br                      float64
#  8   km                      object
#  9   municipio               object
#  10  causa_principal         object
#  11  causa_acidente          object
#  12  ordem_tipo_acidente     int64
#  13  tipo_acidente           object
#  14  classificacao_acidente  object
#  15  fase_dia                object
#  16  sentido_via             object
#  17  condicao_metereologica  object
#  18  tipo_pista              object
#  19  tracado_via             object
#  20  uso_solo                object
#  21  id_veiculo              float64
#  22  tipo_veiculo            object
#  23  marca                   object
#  24  ano_fabricacao_veiculo  float64
#  25  tipo_envolvido          object
#  26  estado_fisico           object
#  27  idade                   float64
#  28  sexo                    object
#  29  ilesos                  int64
#  30  feridos_leves           int64
#  31  feridos_graves          int64
#  32  mortos                  int64
#  33  latitude                object
#  34  longitude               object
#  35  regional                object
#  36  delegacia               object
#  37  uop                     object
# dtypes: float64(6), int64(6), object(26)
# memory usage: 686.5+ MB

# %%
dftrans.isna().sum()
# Out:
# Unnamed: 0                     0
# id                             0
# pesid                     199237
# data_inversa                   0
# dia_semana                     0
# horario                        0
# uf                             0
# br                          5570
# km                          5570
# municipio                      0
# causa_principal                0
# causa_acidente                 0
# ordem_tipo_acidente            0
# tipo_acidente                 96
# classificacao_acidente         1
# fase_dia                       0
# sentido_via                    0
# condicao_metereologica         0
# tipo_pista                     0
# tracado_via                    0
# uso_solo                       0
# id_veiculo                     6
# tipo_veiculo                   0
# marca                     103516
# ano_fabricacao_veiculo    126659
# tipo_envolvido                 0
# estado_fisico                  0
# idade                     462949
# sexo                           0
# ilesos                         0
# feridos_leves                  0
# feridos_graves                 0
# mortos                         0
# latitude                       0
# longitude                      0
# regional                     330
# delegacia                   7791
# uop                         5565
# dtype: int64

# %%
dftrans[['classificacao_acidente','feridos_leves','feridos_graves','mortos']][dftrans['classificacao_acidente'].isna()]
# Out:
#         classificacao_acidente  feridos_leves  feridos_graves  mortos
# 1149763                    NaN              0               0       0

# %%
# Altera a maneira que o Pandas mostra as colunas
pd.set_option('display.max_columns', None) # default:0, None mostra todas as colunas
pd.set_option('display.max_colwidth', 50) # defaul:50, None mostra o conteúdo completo das colunas

# %%
dftrans[dftrans['classificacao_acidente'].isna()]
# Out:
#          Unnamed: 0        id  pesid data_inversa dia_semana   horario  uf
# 1149763     1149763  288395.0    NaN   2020-06-06     sábado  02:50:00  SC  \
#
#             br   km municipio causa_principal      causa_acidente
# 1149763  470.0  1,5    ILHOTA             Sim  Pista Escorregadia  \
#
#          ordem_tipo_acidente tipo_acidente classificacao_acidente
# 1149763                    1           NaN                    NaN  \
#
#             fase_dia  sentido_via condicao_metereologica tipo_pista
# 1149763  Plena Noite  Decrescente                  Chuva    Simples  \
#
#         tracado_via uso_solo  id_veiculo   tipo_veiculo marca
# 1149763        Reta      Não         NaN  Não Informado   NaN  \
#
#          ano_fabricacao_veiculo tipo_envolvido  estado_fisico  idade
# 1149763                     NaN  Não Informado  Não Informado    NaN  \
#
#                   sexo  ilesos  feridos_leves  feridos_graves  mortos
# 1149763  Não Informado       0              0               0       0  \
#
#           latitude longitude regional delegacia             uop
# 1149763 -26.900204 -48.82765  SPRF-SC  DEL04-SC  UOP04-DEL04-SC

# %%
dftrans[dftrans['ilesos'] == 1 & dftrans['classificacao_acidente'] == 'Sem Vítimas']

#udemy_pago = len(udemy_cursos[udemy_cursos["is_paid"]==True])
# Out:
#          Unnamed: 0        id      pesid data_inversa   dia_semana   horario
# 1                 1       9.0      955.0   2017-01-01      domingo  00:01:00  \
# 7                 7      14.0     1558.0   2017-01-01      domingo  00:40:00
# 9                 9      14.0     1558.0   2017-01-01      domingo  00:40:00
# 11               11      16.0     1913.0   2017-01-01      domingo  00:30:00
# 14               14      16.0     1913.0   2017-01-01      domingo  00:30:00
# ...             ...       ...        ...          ...          ...       ...
# 2367892     2367892  501999.0  1096529.0   2022-11-08  terça-feira  09:20:00
# 2367897     2367897  501999.0  1096529.0   2022-11-08  terça-feira  09:20:00
# 2367902     2367902  501999.0  1096529.0   2022-11-08  terça-feira  09:20:00
# 2367907     2367907  501999.0  1096529.0   2022-11-08  terça-feira  09:20:00
# 2367912     2367912  501999.0  1096529.0   2022-11-08  terça-feira  09:20:00
#
#          uf     br     km  municipio causa_principal
# 1        SC  101.0    234    PALHOCA             Sim  \
# 7        GO   60.0    188      GUAPO             Sim
# 9        GO   60.0    188      GUAPO             Não
# 11       TO  153.0  141,7  ARAGUAINA             Sim
# 14       TO  153.0  141,7  ARAGUAINA             Sim
# ...      ..    ...    ...        ...             ...
# 2367892  RO  364.0     14    VILHENA             Sim
# 2367897  RO  364.0     14    VILHENA             Sim
# 2367902  RO  364.0     14    VILHENA             Não
# 2367907  RO  364.0     14    VILHENA             Não
# 2367912  RO  364.0     14    VILHENA             Não
#
#                                    causa_acidente  ordem_tipo_acidente
# 1                     Falta de Atenção à Condução                    1  \
# 7                     Falta de Atenção à Condução                    1
# 9              Não guardar distância de segurança                    1
# 11                             Ingestão de Álcool                    1
# 14                             Ingestão de Álcool                    1
# ...                                           ...                  ...
# 2367892               Manobra de mudança de faixa                    2
# 2367897               Manobra de mudança de faixa                    1
# 2367902  Reação tardia ou ineficiente do condutor                    3
# 2367907  Reação tardia ou ineficiente do condutor                    2
# 2367912  Reação tardia ou ineficiente do condutor                    1
#
#                          tipo_acidente classificacao_acidente     fase_dia
# 1          Colisão com objeto estático            Sem Vítimas  Plena Noite  \
# 7                     Colisão traseira    Com Vítimas Feridas  Plena Noite
# 9                     Colisão traseira    Com Vítimas Feridas  Plena Noite
# 11                    Colisão traseira    Com Vítimas Feridas  Plena Noite
# 14                    Colisão traseira    Com Vítimas Feridas  Plena Noite
# ...                                ...                    ...          ...
# 2367892                     Tombamento    Com Vítimas Feridas    Pleno dia
# 2367897  Colisão lateral mesmo sentido    Com Vítimas Feridas    Pleno dia
# 2367902   Queda de ocupante de veículo    Com Vítimas Feridas    Pleno dia
# 2367907                     Tombamento    Com Vítimas Feridas    Pleno dia
# 2367912  Colisão lateral mesmo sentido    Com Vítimas Feridas    Pleno dia
#
#          sentido_via condicao_metereologica tipo_pista         tracado_via
# 1          Crescente                  Chuva      Dupla               Curva  \
# 7        Decrescente                Nublado      Dupla                Reta
# 9        Decrescente                Nublado      Dupla                Reta
# 11       Decrescente               Ignorado   Múltipla                Reta
# 14       Decrescente               Ignorado   Múltipla                Reta
# ...              ...                    ...        ...                 ...
# 2367892  Decrescente              Céu Claro      Dupla  Interseção de vias
# 2367897  Decrescente              Céu Claro      Dupla  Interseção de vias
# 2367902  Decrescente              Céu Claro      Dupla  Interseção de vias
# 2367907  Decrescente              Céu Claro      Dupla  Interseção de vias
# 2367912  Decrescente              Céu Claro      Dupla  Interseção de vias
#
#         uso_solo  id_veiculo     tipo_veiculo
# 1            Não         7.0        Automóvel  \
# 7            Sim      1309.0        Automóvel
# 9            Sim      1309.0        Automóvel
# 11           Sim       373.0         Motoneta
# 14           Sim      1617.0        Automóvel
# ...          ...         ...              ...
# 2367892      Sim    883510.0  Caminhão-trator
# 2367897      Sim    883510.0  Caminhão-trator
# 2367902      Sim    883510.0  Caminhão-trator
# 2367907      Sim    883510.0  Caminhão-trator
# 2367912      Sim    883510.0  Caminhão-trator
#
#                                                      marca
# 1        FIAT/PALIO WEEKEND EX/PALIO WEEKEND EX/PALIO W...  \
# 7        RENAULT/CLIO RN 1.0 16V/CLIO RN 1.0 16V/CLIO R...
# 9        RENAULT/CLIO RN 1.0 16V/CLIO RN 1.0 16V/CLIO R...
# 11                                                     NaN
# 14                                                     NaN
# ...                                                    ...
# 2367892                                  VOLVO/FH 460 4X2T
# 2367897                                  VOLVO/FH 460 4X2T
# 2367902                                  VOLVO/FH 460 4X2T
# 2367907                                  VOLVO/FH 460 4X2T
# 2367912                                  VOLVO/FH 460 4X2T
#
#          ano_fabricacao_veiculo tipo_envolvido estado_fisico  idade
# 1                        2003.0       Condutor         Ileso   35.0  \
# 7                        2002.0       Condutor         Ileso   35.0
# 9                        2002.0       Condutor         Ileso   35.0
# 11                          NaN       Pedestre         Ileso   45.0
# 14                          NaN       Pedestre         Ileso   45.0
# ...                         ...            ...           ...    ...
# 2367892                  2020.0       Condutor         Ileso   47.0
# 2367897                  2020.0       Condutor         Ileso   47.0
# 2367902                  2020.0       Condutor         Ileso   47.0
# 2367907                  2020.0       Condutor         Ileso   47.0
# 2367912                  2020.0       Condutor         Ileso   47.0
#
#               sexo  ilesos  feridos_leves  feridos_graves  mortos
# 1        Masculino       1              0               0       0  \
# 7        Masculino       1              0               0       0
# 9        Masculino       1              0               0       0
# 11       Masculino       1              0               0       0
# 14       Masculino       1              0               0       0
# ...            ...     ...            ...             ...     ...
# 2367892   Feminino       1              0               0       0
# 2367897   Feminino       1              0               0       0
# 2367902   Feminino       1              0               0       0
# 2367907   Feminino       1              0               0       0
# 2367912   Feminino       1              0               0       0
#
#              latitude     longitude regional delegacia             uop
# 1            -27,8101      -48,6357  SPRF-SC  DEL01-SC  UOP02-DEL01-SC
# 7        -16,82489647  -49,53520775  SPRF-GO  DEL01-GO  UOP02-DEL01-GO
# 9        -16,82489647  -49,53520775  SPRF-GO  DEL01-GO  UOP02-DEL01-GO
# 11        -7,18668515  -48,22970957  SPRF-TO  DEL02-TO  UOP01-DEL02-TO
# 14        -7,18668515  -48,22970957  SPRF-TO  DEL02-TO  UOP01-DEL02-TO
# ...               ...           ...      ...       ...             ...
# 2367892  -12,73892486  -60,13953567  SPRF-RO  DEL04-RO  UOP01-DEL04-RO
# 2367897  -12,73892486  -60,13953567  SPRF-RO  DEL04-RO  UOP01-DEL04-RO
# 2367902  -12,73892486  -60,13953567  SPRF-RO  DEL04-RO  UOP01-DEL04-RO
# 2367907  -12,73892486  -60,13953567  SPRF-RO  DEL04-RO  UOP01-DEL04-RO
# 2367912  -12,73892486  -60,13953567  SPRF-RO  DEL04-RO  UOP01-DEL04-RO
#
# [881464 rows x 38 columns]

# %%
dftrans[(dftrans['ilesos'] == 1) & (dftrans['classificacao_acidente'] == 'Sem Vítimas')]
# Out:
#          Unnamed: 0        id      pesid data_inversa     dia_semana
# 1                 1       9.0      955.0   2017-01-01        domingo  \
# 101             101      25.0       31.0   2017-01-01        domingo
# 102             102      26.0       18.0   2017-01-01        domingo
# 104             104      30.0       16.0   2017-01-01        domingo
# 105             105      30.0       17.0   2017-01-01        domingo
# ...             ...       ...        ...          ...            ...
# 2367222     2367222  500833.0  1093571.0   2022-11-21  segunda-feira
# 2367223     2367223  500833.0  1093573.0   2022-11-21  segunda-feira
# 2367224     2367224  500833.0  1093572.0   2022-11-21  segunda-feira
# 2367225     2367225  500833.0  1093571.0   2022-11-21  segunda-feira
# 2367310     2367310  501059.0  1094151.0   2022-10-30        domingo
#
#           horario  uf     br     km              municipio causa_principal
# 1        00:01:00  SC  101.0    234                PALHOCA             Sim  \
# 101      00:30:00  MS  262.0   34,5            TRES LAGOAS             Sim
# 102      00:30:00  GO   20.0   21,5                FORMOSA             Sim
# 104      02:20:00  SP  153.0   63,3  SAO JOSE DO RIO PRETO             Sim
# 105      02:20:00  SP  153.0   63,3  SAO JOSE DO RIO PRETO             Sim
# ...           ...  ..    ...    ...                    ...             ...
# 2367222  09:20:00  GO  153.0  342,7                JARAGUA             Não
# 2367223  09:20:00  GO  153.0  342,7                JARAGUA             Sim
# 2367224  09:20:00  GO  153.0  342,7                JARAGUA             Sim
# 2367225  09:20:00  GO  153.0  342,7                JARAGUA             Sim
# 2367310  22:27:00  SE  101.0    6,7      CEDRO DE SAO JOAO             Sim
#
#                                             causa_acidente
# 1                              Falta de Atenção à Condução  \
# 101                                       Animais na Pista
# 102                                     Ingestão de Álcool
# 104                                     Ingestão de Álcool
# 105                                     Ingestão de Álcool
# ...                                                    ...
# 2367222                     Ausência de reação do condutor
# 2367223  Condutor deixou de manter distância do veículo...
# 2367224  Condutor deixou de manter distância do veículo...
# 2367225  Condutor deixou de manter distância do veículo...
# 2367310                             Transitar na contramão
#
#          ordem_tipo_acidente                tipo_acidente
# 1                          1  Colisão com objeto estático  \
# 101                        1      Atropelamento de Animal
# 102                        1    Saída de leito carroçável
# 104                        1             Colisão traseira
# 105                        1             Colisão traseira
# ...                      ...                          ...
# 2367222                    1             Colisão traseira
# 2367223                    1             Colisão traseira
# 2367224                    1             Colisão traseira
# 2367225                    1             Colisão traseira
# 2367310                    1              Colisão frontal
#
#         classificacao_acidente     fase_dia  sentido_via
# 1                  Sem Vítimas  Plena Noite    Crescente  \
# 101                Sem Vítimas  Plena Noite  Decrescente
# 102                Sem Vítimas  Plena Noite  Decrescente
# 104                Sem Vítimas  Plena Noite  Decrescente
# 105                Sem Vítimas  Plena Noite  Decrescente
# ...                        ...          ...          ...
# 2367222            Sem Vítimas    Pleno dia  Decrescente
# 2367223            Sem Vítimas    Pleno dia  Decrescente
# 2367224            Sem Vítimas    Pleno dia  Decrescente
# 2367225            Sem Vítimas    Pleno dia  Decrescente
# 2367310            Sem Vítimas  Plena Noite  Decrescente
#
#         condicao_metereologica tipo_pista         tracado_via uso_solo
# 1                        Chuva      Dupla               Curva      Não  \
# 101                  Céu Claro    Simples                Reta      Não
# 102                  Céu Claro    Simples  Interseção de vias      Não
# 104                  Céu Claro      Dupla               Curva      Sim
# 105                  Céu Claro      Dupla               Curva      Sim
# ...                        ...        ...                 ...      ...
# 2367222              Céu Claro    Simples       Não Informado      Não
# 2367223              Céu Claro    Simples       Não Informado      Não
# 2367224              Céu Claro    Simples       Não Informado      Não
# 2367225              Céu Claro    Simples       Não Informado      Não
# 2367310              Céu Claro      Dupla       Não Informado      Não
#
#          id_veiculo tipo_veiculo
# 1               7.0    Automóvel  \
# 101            36.0    Automóvel
# 102            20.0    Automóvel
# 104            18.0    Automóvel
# 105            18.0    Automóvel
# ...             ...          ...
# 2367222    881248.0  Caminhonete
# 2367223    881250.0    Automóvel
# 2367224    881249.0     Caminhão
# 2367225    881248.0  Caminhonete
# 2367310    881677.0  Caminhonete
#
#                                                      marca
# 1        FIAT/PALIO WEEKEND EX/PALIO WEEKEND EX/PALIO W...  \
# 101      FIAT/SIENA FIRE FLEX/SIENA FIRE FLEX/SIENA FIR...
# 102      FIAT/PALIO WK TREKK 1.6/PALIO WK TREKK 1.6/PAL...
# 104      CHEVROLET/CELTA 1.0L LT/CELTA 1.0L LT/CELTA 1....
# 105      CHEVROLET/CELTA 1.0L LT/CELTA 1.0L LT/CELTA 1....
# ...                                                    ...
# 2367222                            RENAULT/MASTER FUR L2H2
# 2367223                           FIAT/SIENA ESSENC 1.6 DL
# 2367224                                  VW/24.260 CRM 6X2
# 2367225                            RENAULT/MASTER FUR L2H2
# 2367310                            FIAT/TORO FREEDOM AT9 D
#
#          ano_fabricacao_veiculo tipo_envolvido estado_fisico  idade
# 1                        2003.0       Condutor         Ileso   35.0  \
# 101                      2007.0       Condutor         Ileso   41.0
# 102                      2013.0       Condutor         Ileso   34.0
# 104                      2014.0       Condutor         Ileso   22.0
# 105                      2014.0     Passageiro         Ileso   24.0
# ...                         ...            ...           ...    ...
# 2367222                  2021.0       Condutor         Ileso   75.0
# 2367223                  2011.0       Condutor         Ileso   26.0
# 2367224                  2021.0       Condutor         Ileso   34.0
# 2367225                  2021.0       Condutor         Ileso   75.0
# 2367310                  2018.0       Condutor         Ileso   32.0
#
#               sexo  ilesos  feridos_leves  feridos_graves  mortos
# 1        Masculino       1              0               0       0  \
# 101      Masculino       1              0               0       0
# 102      Masculino       1              0               0       0
# 104      Masculino       1              0               0       0
# 105      Masculino       1              0               0       0
# ...            ...     ...            ...             ...     ...
# 2367222  Masculino       1              0               0       0
# 2367223  Masculino       1              0               0       0
# 2367224  Masculino       1              0               0       0
# 2367225  Masculino       1              0               0       0
# 2367310  Masculino       1              0               0       0
#
#              latitude     longitude regional delegacia             uop
# 1            -27,8101      -48,6357  SPRF-SC  DEL01-SC  UOP02-DEL01-SC
# 101      -20,78594796  -51,92953072  SPRF-MS  DEL07-MS  UOP01-DEL07-MS
# 102      -15,54699656  -47,16523376  SPRF-DF  DEL02-DF  UOP01-DEL02-DF
# 104      -20,82376296  -49,35789764  SPRF-SP  DEL09-SP  UOP01-DEL09-SP
# 105      -20,82376296  -49,35789764  SPRF-SP  DEL09-SP  UOP01-DEL09-SP
# ...               ...           ...      ...       ...             ...
# 2367222     -15,61235    -49,401028  SPRF-GO  DEL02-GO  UOP02-DEL02-GO
# 2367223     -15,61235    -49,401028  SPRF-GO  DEL02-GO  UOP02-DEL02-GO
# 2367224     -15,61235    -49,401028  SPRF-GO  DEL02-GO  UOP02-DEL02-GO
# 2367225     -15,61235    -49,401028  SPRF-GO  DEL02-GO  UOP02-DEL02-GO
# 2367310  -10,24797206  -36,85696789  SPRF-SE  DEL02-SE  UOP02-DEL02-SE
#
# [259423 rows x 38 columns]

# %%
dftrans['classificacao_acidente'].unique()
# Out:
# array(['Com Vítimas Feridas', 'Sem Vítimas', 'Com Vítimas Fatais', nan],
#       dtype=object)

# %%
dftrans['pesid'].isna()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2367910     True
# 2367911     True
# 2367912    False
# 2367913    False
# 2367914    False
# Name: pesid, Length: 2367915, dtype: bool

# %%
dftrans.iloc[2367911:2367914]
# Out:
#          Unnamed: 0        id      pesid data_inversa   dia_semana   horario
# 2367911     2367911  501999.0        NaN   2022-11-08  terça-feira  09:20:00  \
# 2367912     2367912  501999.0  1096529.0   2022-11-08  terça-feira  09:20:00
# 2367913     2367913  501999.0  1096530.0   2022-11-08  terça-feira  09:20:00
#
#          uf     br  km municipio  ...           sexo ilesos  feridos_leves
# 2367911  RO  364.0  14   VILHENA  ...  Não Informado      0              0  \
# 2367912  RO  364.0  14   VILHENA  ...       Feminino      1              0
# 2367913  RO  364.0  14   VILHENA  ...       Feminino      0              0
#
#         feridos_graves mortos      latitude     longitude regional delegacia
# 2367911              0      0  -12,73892486  -60,13953567  SPRF-RO  DEL04-RO  \
# 2367912              0      0  -12,73892486  -60,13953567  SPRF-RO  DEL04-RO
# 2367913              1      0  -12,73892486  -60,13953567  SPRF-RO  DEL04-RO
#
#                     uop
# 2367911  UOP01-DEL04-RO
# 2367912  UOP01-DEL04-RO
# 2367913  UOP01-DEL04-RO
#
# [3 rows x 38 columns]
